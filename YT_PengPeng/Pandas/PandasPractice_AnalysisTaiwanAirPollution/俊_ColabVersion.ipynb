# %%
import json
import codecs
import pandas as pd
import matplotlib.pyplot as plt 

import ipywidgets as widgets

# %matplotlib inline

# %%
with codecs.open('AQI1.json', 'r', encoding='utf-8') as file:
    content_json = file.read()
    
content = json.loads(content_json)
content
# Out:
# [{'sitename': '基隆',
#   'county': '基隆市',
#   'aqi': '39',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.3',
#   'co': '0.25',
#   'o3': '39.8',
#   'o3_8hr': '42.2',
#   'pm10': '21',
#   'pm2.5': '8',
#   'no2': '6.2',
#   'nox': '7.5',
#   'no': '1.3',
#   'wind_speed': '0.9',
#   'wind_direc': '66',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '6',
#   'pm10_avg': '15',
#   'so2_avg': '0',
#   'longitude': '121.760056',
#   'latitude': '25.129167',
#   'siteid': '1'},
#  {'sitename': '汐止',
#   'county': '新北市',
#   'aqi': '31',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.2',
#   'co': '0.27',
#   'o3': '33.3',
#   'o3_8hr': '33.8',
#   'pm10': '4',
#   'pm2.5': '7',
#   'no2': '13.2',
#   'nox': '15.2',
#   'no': '1.9',
#   'wind_speed': '2',
#   'wind_direc': '48',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '4',
#   'pm10_avg': '7',
#   'so2_avg': '0',
#   'longitude': '121.6423',
#   'latitude': '25.067131',
#   'siteid': '2'},
#  {'sitename': '萬里',
#   'county': '新北市',
#   'aqi': '42',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.4',
#   'co': '0.19',
#   'o3': '45.8',
#   'o3_8hr': '45.6',
#   'pm10': '45',
#   'pm2.5': '20',
#   'no2': '1.6',
#   'nox': '2.6',
#   'no': '1',
#   'wind_speed': '5.1',
#   'wind_direc': '19',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '10',
#   'pm10_avg': '35',
#   'so2_avg': '0',
#   'longitude': '121.689881',
#   'latitude': '25.179667',
#   'siteid': '3'},
#  {'sitename': '新店',
#   'county': '新北市',
#   'aqi': '28',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.7',
#   'co': '0.38',
#   'o3': '27.2',
#   'o3_8hr': '28.9',
#   'pm10': '7',
#   'pm2.5': '6',
#   'no2': '17.4',
#   'nox': '19.9',
#   'no': '2.5',
#   'wind_speed': '0.9',
#   'wind_direc': '115',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '3',
#   'pm10_avg': '6',
#   'so2_avg': '0',
#   'longitude': '121.537778',
#   'latitude': '24.977222',
#   'siteid': '4'},
#  {'sitename': '土城',
#   'county': '新北市',
#   'aqi': '31',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.8',
#   'co': '0.35',
#   'o3': '28.9',
#   'o3_8hr': '33.3',
#   'pm10': '10',
#   'pm2.5': '4',
#   'no2': '16.2',
#   'nox': '18.9',
#   'no': '2.7',
#   'wind_speed': '1.5',
#   'wind_direc': '66',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '2',
#   'pm10_avg': '8',
#   'so2_avg': '0',
#   'longitude': '121.451861',
#   'latitude': '24.982528',
#   'siteid': '5'},
#  {'sitename': '板橋',
#   'county': '新北市',
#   'aqi': '40',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.6',
#   'co': '0.53',
#   'o3': '20.2',
#   'o3_8hr': '23.5',
#   'pm10': '16',
#   'pm2.5': '5',
#   'no2': '24.7',
#   'nox': '29',
#   'no': '4.3',
#   'wind_speed': '1.3',
#   'wind_direc': '154',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '4',
#   'pm10_avg': '7',
#   'so2_avg': '0',
#   'longitude': '121.458667',
#   'latitude': '25.012972',
#   'siteid': '6'},
#  {'sitename': '新莊',
#   'county': '新北市',
#   'aqi': '40',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.4',
#   'co': '0.53',
#   'o3': '19.1',
#   'o3_8hr': '23.3',
#   'pm10': '13',
#   'pm2.5': '7',
#   'no2': '24.6',
#   'nox': '29.4',
#   'no': '4.7',
#   'wind_speed': '0.7',
#   'wind_direc': '355',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '5',
#   'pm10_avg': '12',
#   'so2_avg': '0',
#   'longitude': '121.4325',
#   'latitude': '25.037972',
#   'siteid': '7'},
#  {'sitename': '菜寮',
#   'county': '新北市',
#   'aqi': '35',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.6',
#   'o3': '24.1',
#   'o3_8hr': '21.2',
#   'pm10': '11',
#   'pm2.5': '8',
#   'no2': '21.3',
#   'nox': '25',
#   'no': '3.7',
#   'wind_speed': '1.5',
#   'wind_direc': '107',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '6',
#   'pm10_avg': '9',
#   'so2_avg': '0',
#   'longitude': '121.481028',
#   'latitude': '25.06895',
#   'siteid': '8'},
#  {'sitename': '林口',
#   'county': '新北市',
#   'aqi': '30',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.5',
#   'co': '0.23',
#   'o3': '28.5',
#   'o3_8hr': '32.6',
#   'pm10': '11',
#   'pm2.5': '8',
#   'no2': '15.9',
#   'nox': '19.9',
#   'no': '3.9',
#   'wind_speed': '3.9',
#   'wind_direc': '36',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '4',
#   'pm10_avg': '7',
#   'so2_avg': '0',
#   'longitude': '121.36548982',
#   'latitude': '25.07798949',
#   'siteid': '9'},
#  {'sitename': '淡水',
#   'county': '新北市',
#   'aqi': '35',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.4',
#   'co': '0.22',
#   'o3': '40.1',
#   'o3_8hr': '38.5',
#   'pm10': '5',
#   'pm2.5': '7',
#   'no2': '3.5',
#   'nox': '4.2',
#   'no': '0.6',
#   'wind_speed': '',
#   'wind_direc': '',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '4',
#   'pm10_avg': '6',
#   'so2_avg': '0',
#   'longitude': '121.449239',
#   'latitude': '25.1645',
#   'siteid': '10'},
#  {'sitename': '士林',
#   'county': '臺北市',
#   'aqi': '38',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.8',
#   'co': '0.37',
#   'o3': '18.4',
#   'o3_8hr': '21.4',
#   'pm10': '23',
#   'pm2.5': '8',
#   'no2': '23.3',
#   'nox': '32.8',
#   'no': '9.5',
#   'wind_speed': '1.1',
#   'wind_direc': '258',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '5',
#   'pm10_avg': '12',
#   'so2_avg': '0',
#   'longitude': '121.51666356',
#   'latitude': '25.10334003',
#   'siteid': '11'},
#  {'sitename': '中山',
#   'county': '臺北市',
#   'aqi': '42',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.61',
#   'o3': '18.8',
#   'o3_8hr': '24.2',
#   'pm10': '15',
#   'pm2.5': '5',
#   'no2': '25.5',
#   'nox': '34.8',
#   'no': '9.2',
#   'wind_speed': '2.4',
#   'wind_direc': '118',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '4',
#   'pm10_avg': '9',
#   'so2_avg': '0',
#   'longitude': '121.526528',
#   'latitude': '25.062361',
#   'siteid': '12'},
#  {'sitename': '萬華',
#   'county': '臺北市',
#   'aqi': '47',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.7',
#   'co': '0.52',
#   'o3': '15.1',
#   'o3_8hr': '20.1',
#   'pm10': '15',
#   'pm2.5': '9',
#   'no2': '28.5',
#   'nox': '36.6',
#   'no': '8',
#   'wind_speed': '2.4',
#   'wind_direc': '102',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '7',
#   'pm10_avg': '8',
#   'so2_avg': '0',
#   'longitude': '121.507972',
#   'latitude': '25.046503',
#   'siteid': '13'},
#  {'sitename': '古亭',
#   'county': '臺北市',
#   'aqi': '30',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.3',
#   'co': '0.38',
#   'o3': '25.4',
#   'o3_8hr': '32.2',
#   'pm10': '9',
#   'pm2.5': '9',
#   'no2': '16.7',
#   'nox': '20.1',
#   'no': '3.4',
#   'wind_speed': '1.8',
#   'wind_direc': '58',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '8',
#   'pm10_avg': '8',
#   'so2_avg': '0',
#   'longitude': '121.529556',
#   'latitude': '25.020608',
#   'siteid': '14'},
#  {'sitename': '松山',
#   'county': '臺北市',
#   'aqi': '37',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.8',
#   'co': '0.37',
#   'o3': '22.8',
#   'o3_8hr': '29.6',
#   'pm10': '16',
#   'pm2.5': '8',
#   'no2': '22.5',
#   'nox': '29',
#   'no': '6.4',
#   'wind_speed': '2.6',
#   'wind_direc': '62',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '6',
#   'pm10_avg': '13',
#   'so2_avg': '0',
#   'longitude': '121.578611',
#   'latitude': '25.05',
#   'siteid': '15'},
#  {'sitename': '大同',
#   'county': '臺北市',
#   'aqi': '55',
#   'pollutant': '二氧化氮',
#   'status': '普通',
#   'so2': '0.8',
#   'co': '1.13',
#   'o3': '9.4',
#   'o3_8hr': '13.1',
#   'pm10': '25',
#   'pm2.5': '13',
#   'no2': '36.7',
#   'nox': '83.8',
#   'no': '47',
#   'wind_speed': '-',
#   'wind_direc': '-',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '1',
#   'pm2.5_avg': '11',
#   'pm10_avg': '22',
#   'so2_avg': '0',
#   'longitude': '121.51342074',
#   'latitude': '25.06331455',
#   'siteid': '16'},
#  {'sitename': '桃園',
#   'county': '桃園市',
#   'aqi': '43',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.1',
#   'co': '0.6',
#   'o3': '16.5',
#   'o3_8hr': '23',
#   'pm10': '20',
#   'pm2.5': '9',
#   'no2': '26.3',
#   'nox': '30.8',
#   'no': '4.4',
#   'wind_speed': '1.7',
#   'wind_direc': '28',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '5',
#   'pm10_avg': '9',
#   'so2_avg': '0',
#   'longitude': '121.30500531',
#   'latitude': '24.9947107',
#   'siteid': '17'},
#  {'sitename': '大園',
#   'county': '桃園市',
#   'aqi': '42',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '2.8',
#   'co': '0.28',
#   'o3': '24.4',
#   'o3_8hr': '32.5',
#   'pm10': '32',
#   'pm2.5': '8',
#   'no2': '25.9',
#   'nox': '34.2',
#   'no': '8.3',
#   'wind_speed': '5.2',
#   'wind_direc': '38',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '6',
#   'pm10_avg': '16',
#   'so2_avg': '2',
#   'longitude': '121.20251473',
#   'latitude': '25.06100357',
#   'siteid': '18'},
#  {'sitename': '觀音',
#   'county': '桃園市',
#   'aqi': '38',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.6',
#   'co': '0.19',
#   'o3': '40.8',
#   'o3_8hr': '41.2',
#   'pm10': '23',
#   'pm2.5': '11',
#   'no2': '5.9',
#   'nox': '6.6',
#   'no': '0.6',
#   'wind_speed': '4.9',
#   'wind_direc': '57',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '7',
#   'pm10_avg': '16',
#   'so2_avg': '0',
#   'longitude': '121.08283092',
#   'latitude': '25.03556747',
#   'siteid': '19'},
#  {'sitename': '平鎮',
#   'county': '桃園市',
#   'aqi': '47',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.56',
#   'o3': '18.5',
#   'o3_8hr': '27.2',
#   'pm10': '17',
#   'pm2.5': '11',
#   'no2': '28',
#   'nox': '33.5',
#   'no': '5.4',
#   'wind_speed': '3.1',
#   'wind_direc': '28',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '8',
#   'pm10_avg': '10',
#   'so2_avg': '1',
#   'longitude': '121.203986',
#   'latitude': '24.952786',
#   'siteid': '20'},
#  {'sitename': '龍潭',
#   'county': '桃園市',
#   'aqi': '31',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.3',
#   'co': '0.27',
#   'o3': '34.2',
#   'o3_8hr': '33.9',
#   'pm10': '4',
#   'pm2.5': '0',
#   'no2': '9.6',
#   'nox': '12.6',
#   'no': '2.9',
#   'wind_speed': '5.1',
#   'wind_direc': '53',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '1',
#   'pm10_avg': '3',
#   'so2_avg': '1',
#   'longitude': '121.21645772',
#   'latitude': '24.86400048',
#   'siteid': '21'},
#  {'sitename': '湖口',
#   'county': '新竹縣',
#   'aqi': '34',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.24',
#   'o3': '37.1',
#   'o3_8hr': '37.3',
#   'pm10': '20',
#   'pm2.5': '7',
#   'no2': '7.3',
#   'nox': '8.4',
#   'no': '1',
#   'wind_speed': '4.7',
#   'wind_direc': '54',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '5',
#   'pm10_avg': '13',
#   'so2_avg': '0',
#   'longitude': '121.03886894',
#   'latitude': '24.90009696',
#   'siteid': '22'},
#  {'sitename': '竹東',
#   'county': '新竹縣',
#   'aqi': '34',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.6',
#   'co': '0.21',
#   'o3': '38.5',
#   'o3_8hr': '37.2',
#   'pm10': '5',
#   'pm2.5': '4',
#   'no2': '6.9',
#   'nox': '8.4',
#   'no': '1.5',
#   'wind_speed': '3.2',
#   'wind_direc': '39',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '5',
#   'pm10_avg': '4',
#   'so2_avg': '0',
#   'longitude': '121.08895493',
#   'latitude': '24.74091408',
#   'siteid': '23'},
#  {'sitename': '新竹',
#   'county': '新竹市',
#   'aqi': '30',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.5',
#   'co': '0.3',
#   'o3': '31.4',
#   'o3_8hr': '32.9',
#   'pm10': '12',
#   'pm2.5': '8',
#   'no2': '11.1',
#   'nox': '13',
#   'no': '1.9',
#   'wind_speed': '3.1',
#   'wind_direc': '35',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '6',
#   'pm10_avg': '11',
#   'so2_avg': '1',
#   'longitude': '120.97236752',
#   'latitude': '24.8056356',
#   'siteid': '24'},
#  {'sitename': '頭份',
#   'county': '苗栗縣',
#   'aqi': '30',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '2',
#   'co': '0.34',
#   'o3': '30.6',
#   'o3_8hr': '32.1',
#   'pm10': '18',
#   'pm2.5': '17',
#   'no2': '12.6',
#   'nox': '15.9',
#   'no': '3.2',
#   'wind_speed': '2.5',
#   'wind_direc': '29',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '8',
#   'pm10_avg': '11',
#   'so2_avg': '1',
#   'longitude': '120.89869286',
#   'latitude': '24.69690679',
#   'siteid': '25'},
#  {'sitename': '苗栗',
#   'county': '苗栗縣',
#   'aqi': '29',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.7',
#   'co': '0.3',
#   'o3': '28.7',
#   'o3_8hr': '31.8',
#   'pm10': '10',
#   'pm2.5': '9',
#   'no2': '12.5',
#   'nox': '14.8',
#   'no': '2.3',
#   'wind_speed': '2.9',
#   'wind_direc': '12',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '5',
#   'pm10_avg': '9',
#   'so2_avg': '1',
#   'longitude': '120.82011468',
#   'latitude': '24.56499183',
#   'siteid': '26'},
#  {'sitename': '三義',
#   'county': '苗栗縣',
#   'aqi': '28',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.21',
#   'o3': '30.6',
#   'o3_8hr': '30',
#   'pm10': '13',
#   'pm2.5': '6',
#   'no2': '6.8',
#   'nox': '8.3',
#   'no': '1.4',
#   'wind_speed': '4.8',
#   'wind_direc': '23',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '5',
#   'pm10_avg': '7',
#   'so2_avg': '0',
#   'longitude': '120.75956754',
#   'latitude': '24.38248443',
#   'siteid': '27'},
#  {'sitename': '豐原',
#   'county': '臺中市',
#   'aqi': '14',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.18',
#   'o3': '21.7',
#   'o3_8hr': '15',
#   'pm10': '6',
#   'pm2.5': '3',
#   'no2': '3.1',
#   'nox': '4.5',
#   'no': '1.4',
#   'wind_speed': '2.8',
#   'wind_direc': '26',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '4',
#   'pm10_avg': '5',
#   'so2_avg': '0',
#   'longitude': '120.74252414',
#   'latitude': '24.25699731',
#   'siteid': '28'},
#  {'sitename': '沙鹿',
#   'county': '臺中市',
#   'aqi': '29',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.8',
#   'co': '0.21',
#   'o3': '34.6',
#   'o3_8hr': '31.6',
#   'pm10': '14',
#   'pm2.5': '10',
#   'no2': '7.4',
#   'nox': '9.7',
#   'no': '2.3',
#   'wind_speed': '5.4',
#   'wind_direc': '12',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '6',
#   'pm10_avg': '12',
#   'so2_avg': '1',
#   'longitude': '120.568794',
#   'latitude': '24.225628',
#   'siteid': '29'},
#  {'sitename': '大里',
#   'county': '臺中市',
#   'aqi': '31',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.27',
#   'o3': '25.8',
#   'o3_8hr': '7.8',
#   'pm10': '8',
#   'pm2.5': '3',
#   'no2': '6.8',
#   'nox': '10.1',
#   'no': '3.3',
#   'wind_speed': '1.9',
#   'wind_direc': '27',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '9',
#   'pm10_avg': '18',
#   'so2_avg': '1',
#   'longitude': '120.67844444',
#   'latitude': '24.09961111',
#   'siteid': '30'},
#  {'sitename': '忠明',
#   'county': '臺中市',
#   'aqi': '19',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.4',
#   'co': '0.27',
#   'o3': '29.6',
#   'o3_8hr': '21.2',
#   'pm10': '23',
#   'pm2.5': '5',
#   'no2': '11.1',
#   'nox': '15.9',
#   'no': '4.7',
#   'wind_speed': '3.4',
#   'wind_direc': '40',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '3',
#   'pm10_avg': '12',
#   'so2_avg': '1',
#   'longitude': '120.641092',
#   'latitude': '24.151958',
#   'siteid': '31'},
#  {'sitename': '西屯',
#   'county': '臺中市',
#   'aqi': '32',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.1',
#   'co': '0.24',
#   'o3': '30.7',
#   'o3_8hr': '28.1',
#   'pm10': '19',
#   'pm2.5': '12',
#   'no2': '10.1',
#   'nox': '14.2',
#   'no': '4.1',
#   'wind_speed': '4',
#   'wind_direc': '15',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '9',
#   'pm10_avg': '14',
#   'so2_avg': '0',
#   'longitude': '120.616917',
#   'latitude': '24.162197',
#   'siteid': '32'},
#  {'sitename': '彰化',
#   'county': '彰化縣',
#   'aqi': '29',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.2',
#   'co': '0.28',
#   'o3': '29.6',
#   'o3_8hr': '24.5',
#   'pm10': '25',
#   'pm2.5': '11',
#   'no2': '12.4',
#   'nox': '18.3',
#   'no': '5.9',
#   'wind_speed': '2.1',
#   'wind_direc': '1',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '8',
#   'pm10_avg': '14',
#   'so2_avg': '0',
#   'longitude': '120.541519',
#   'latitude': '24.066',
#   'siteid': '33'},
#  {'sitename': '線西',
#   'county': '彰化縣',
#   'aqi': '30',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.21',
#   'o3': '36.5',
#   'o3_8hr': '32.4',
#   'pm10': '8',
#   'pm2.5': '7',
#   'no2': '7.8',
#   'nox': '10.5',
#   'no': '2.6',
#   'wind_speed': '6.2',
#   'wind_direc': '41',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '6',
#   'pm10_avg': '11',
#   'so2_avg': '1',
#   'longitude': '120.469061',
#   'latitude': '24.131672',
#   'siteid': '34'},
#  {'sitename': '二林',
#   'county': '彰化縣',
#   'aqi': '28',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.5',
#   'co': '0.23',
#   'o3': '36.3',
#   'o3_8hr': '30.4',
#   'pm10': '21',
#   'pm2.5': '',
#   'no2': '5.5',
#   'nox': '7.3',
#   'no': '1.7',
#   'wind_speed': '4.5',
#   'wind_direc': '29',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '',
#   'pm10_avg': '20',
#   'so2_avg': '1',
#   'longitude': '120.409653',
#   'latitude': '23.925175',
#   'siteid': '35'},
#  {'sitename': '南投',
#   'county': '南投縣',
#   'aqi': '29',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.9',
#   'co': '0.3',
#   'o3': '21.7',
#   'o3_8hr': '5.3',
#   'pm10': '13',
#   'pm2.5': '6',
#   'no2': '10.5',
#   'nox': '16',
#   'no': '5.5',
#   'wind_speed': '1.8',
#   'wind_direc': '26',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '9',
#   'pm10_avg': '19',
#   'so2_avg': '0',
#   'longitude': '120.685306',
#   'latitude': '23.913',
#   'siteid': '36'},
#  {'sitename': '斗六',
#   'county': '雲林縣',
#   'aqi': '47',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.6',
#   'co': '0.28',
#   'o3': '20.8',
#   'o3_8hr': '9',
#   'pm10': '22',
#   'pm2.5': '12',
#   'no2': '7.3',
#   'nox': '12.4',
#   'no': '5.1',
#   'wind_speed': '1.8',
#   'wind_direc': '62',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '14',
#   'pm10_avg': '26',
#   'so2_avg': '1',
#   'longitude': '120.544994',
#   'latitude': '23.711853',
#   'siteid': '37'},
#  {'sitename': '崙背',
#   'county': '雲林縣',
#   'aqi': '31',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '',
#   'co': '',
#   'o3': '32.6',
#   'o3_8hr': '24.1',
#   'pm10': '25',
#   'pm2.5': '9',
#   'no2': '',
#   'nox': '',
#   'no': '',
#   'wind_speed': '2.4',
#   'wind_direc': '35',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '9',
#   'pm10_avg': '31',
#   'so2_avg': '1',
#   'longitude': '120.348742',
#   'latitude': '23.757547',
#   'siteid': '38'},
#  {'sitename': '新港',
#   'county': '嘉義縣',
#   'aqi': '32',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.9',
#   'co': '0.3',
#   'o3': '27.1',
#   'o3_8hr': '18.6',
#   'pm10': '24',
#   'pm2.5': '14',
#   'no2': '9.8',
#   'nox': '14.9',
#   'no': '5',
#   'wind_speed': '3.5',
#   'wind_direc': '12',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '10',
#   'pm10_avg': '21',
#   'so2_avg': '1',
#   'longitude': '120.345531',
#   'latitude': '23.554839',
#   'siteid': '39'},
#  {'sitename': '朴子',
#   'county': '嘉義縣',
#   'aqi': '40',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.8',
#   'co': '0.28',
#   'o3': '29.8',
#   'o3_8hr': '22.8',
#   'pm10': '22',
#   'pm2.5': '13',
#   'no2': '9.1',
#   'nox': '13.4',
#   'no': '4.3',
#   'wind_speed': '1.6',
#   'wind_direc': '14',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '12',
#   'pm10_avg': '19',
#   'so2_avg': '1',
#   'longitude': '120.24781111',
#   'latitude': '23.46712222',
#   'siteid': '40'},
#  {'sitename': '臺西',
#   'county': '雲林縣',
#   'aqi': '31',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.7',
#   'co': '0.23',
#   'o3': '36.7',
#   'o3_8hr': '33.8',
#   'pm10': '20',
#   'pm2.5': '7',
#   'no2': '7.1',
#   'nox': '9.7',
#   'no': '2.6',
#   'wind_speed': '5',
#   'wind_direc': '23',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '7',
#   'pm10_avg': '17',
#   'so2_avg': '1',
#   'longitude': '120.19933333',
#   'latitude': '23.702175',
#   'siteid': '41'},
#  {'sitename': '嘉義',
#   'county': '嘉義市',
#   'aqi': '32',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '2',
#   'co': '0.3',
#   'o3': '19.9',
#   'o3_8hr': '10.8',
#   'pm10': '15',
#   'pm2.5': '8',
#   'no2': '8.8',
#   'nox': '13.1',
#   'no': '4.3',
#   'wind_speed': '2.9',
#   'wind_direc': '35',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '9',
#   'pm10_avg': '20',
#   'so2_avg': '2',
#   'longitude': '120.44125148',
#   'latitude': '23.46477865',
#   'siteid': '42'},
#  {'sitename': '新營',
#   'county': '臺南市',
#   'aqi': '32',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '2.4',
#   'co': '0.28',
#   'o3': '23.3',
#   'o3_8hr': '11.6',
#   'pm10': '29',
#   'pm2.5': '10',
#   'no2': '8.7',
#   'nox': '12',
#   'no': '3.2',
#   'wind_speed': '',
#   'wind_direc': '',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '9',
#   'pm10_avg': '22',
#   'so2_avg': '2',
#   'longitude': '120.31725',
#   'latitude': '23.305633',
#   'siteid': '43'},
#  {'sitename': '善化',
#   'county': '臺南市',
#   'aqi': '39',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.23',
#   'o3': '23.9',
#   'o3_8hr': '12.4',
#   'pm10': '24',
#   'pm2.5': '11',
#   'no2': '8.1',
#   'nox': '10.9',
#   'no': '2.8',
#   'wind_speed': '3.9',
#   'wind_direc': '11',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '11',
#   'pm10_avg': '22',
#   'so2_avg': '1',
#   'longitude': '120.29740529',
#   'latitude': '23.11337642',
#   'siteid': '44'},
#  {'sitename': '安南',
#   'county': '臺南市',
#   'aqi': '46',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '2',
#   'co': '0.34',
#   'o3': '21.8',
#   'o3_8hr': '12.7',
#   'pm10': '37',
#   'pm2.5': '20',
#   'no2': '11.8',
#   'nox': '17.9',
#   'no': '6.1',
#   'wind_speed': '3',
#   'wind_direc': '29',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '14',
#   'pm10_avg': '24',
#   'so2_avg': '1',
#   'longitude': '120.2175',
#   'latitude': '23.048197',
#   'siteid': '45'},
#  {'sitename': '臺南',
#   'county': '臺南市',
#   'aqi': '57',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.7',
#   'co': '0.62',
#   'o3': '19.4',
#   'o3_8hr': '14.5',
#   'pm10': '35',
#   'pm2.5': '21',
#   'no2': '20.6',
#   'nox': '33.7',
#   'no': '13',
#   'wind_speed': '0.6',
#   'wind_direc': '132',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '17',
#   'pm10_avg': '27',
#   'so2_avg': '1',
#   'longitude': '120.22238056',
#   'latitude': '22.98525833',
#   'siteid': '46'},
#  {'sitename': '美濃',
#   'county': '高雄市',
#   'aqi': '55',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '0.5',
#   'co': '0.27',
#   'o3': '22.5',
#   'o3_8hr': '7.5',
#   'pm10': '28',
#   'pm2.5': '15',
#   'no2': '6.3',
#   'nox': '8.8',
#   'no': '2.4',
#   'wind_speed': '1.1',
#   'wind_direc': '235',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '17',
#   'pm10_avg': '28',
#   'so2_avg': '0',
#   'longitude': '120.530542',
#   'latitude': '22.883583',
#   'siteid': '47'},
#  {'sitename': '橋頭',
#   'county': '高雄市',
#   'aqi': '71',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.3',
#   'co': '0.28',
#   'o3': '22.8',
#   'o3_8hr': '10.3',
#   'pm10': '40',
#   'pm2.5': '27',
#   'no2': '13.8',
#   'nox': '20',
#   'no': '6.2',
#   'wind_speed': '1.4',
#   'wind_direc': '13',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '23',
#   'pm10_avg': '38',
#   'so2_avg': '1',
#   'longitude': '120.305689',
#   'latitude': '22.757506',
#   'siteid': '48'},
#  {'sitename': '仁武',
#   'county': '高雄市',
#   'aqi': '65',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '5',
#   'co': '0.33',
#   'o3': '19.7',
#   'o3_8hr': '7.8',
#   'pm10': '33',
#   'pm2.5': '23',
#   'no2': '22.2',
#   'nox': '33.4',
#   'no': '11.2',
#   'wind_speed': '2',
#   'wind_direc': '2',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '21',
#   'pm10_avg': '31',
#   'so2_avg': '1',
#   'longitude': '120.332631',
#   'latitude': '22.689056',
#   'siteid': '49'},
#  {'sitename': '鳳山',
#   'county': '高雄市',
#   'aqi': '79',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '2',
#   'co': '0.68',
#   'o3': '20.3',
#   'o3_8hr': '6.4',
#   'pm10': '45',
#   'pm2.5': '25',
#   'no2': '21.5',
#   'nox': '30.5',
#   'no': '9',
#   'wind_speed': '0.7',
#   'wind_direc': '259',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '27',
#   'pm10_avg': '40',
#   'so2_avg': '2',
#   'longitude': '120.357422',
#   'latitude': '22.628126',
#   'siteid': '50'},
#  {'sitename': '大寮',
#   'county': '高雄市',
#   'aqi': '72',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '3.2',
#   'co': '0.38',
#   'o3': '18.2',
#   'o3_8hr': '8.5',
#   'pm10': '48',
#   'pm2.5': '25',
#   'no2': '21.8',
#   'nox': '32.6',
#   'no': '10.7',
#   'wind_speed': '1',
#   'wind_direc': '336',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '24',
#   'pm10_avg': '40',
#   'so2_avg': '1',
#   'longitude': '120.425311',
#   'latitude': '22.56413611',
#   'siteid': '51'},
#  {'sitename': '林園',
#   'county': '高雄市',
#   'aqi': '58',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '2',
#   'co': '0.34',
#   'o3': '',
#   'o3_8hr': '5',
#   'pm10': '42',
#   'pm2.5': '19',
#   'no2': '13.7',
#   'nox': '18.4',
#   'no': '4.7',
#   'wind_speed': '1.4',
#   'wind_direc': '29',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '18',
#   'pm10_avg': '43',
#   'so2_avg': '1',
#   'longitude': '120.41175',
#   'latitude': '22.4795',
#   'siteid': '52'},
#  {'sitename': '楠梓',
#   'county': '高雄市',
#   'aqi': '53',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.2',
#   'co': '0.3',
#   'o3': '20.3',
#   'o3_8hr': '8.9',
#   'pm10': '42',
#   'pm2.5': '16',
#   'no2': '13.8',
#   'nox': '19.7',
#   'no': '5.9',
#   'wind_speed': '2.3',
#   'wind_direc': '50',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '16',
#   'pm10_avg': '34',
#   'so2_avg': '1',
#   'longitude': '120.328289',
#   'latitude': '22.733667',
#   'siteid': '53'},
#  {'sitename': '左營',
#   'county': '高雄市',
#   'aqi': '69',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.8',
#   'co': '0.38',
#   'o3': '26',
#   'o3_8hr': '12.1',
#   'pm10': '51',
#   'pm2.5': '24',
#   'no2': '12.9',
#   'nox': '17.1',
#   'no': '4.2',
#   'wind_speed': '2.6',
#   'wind_direc': '18',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '23',
#   'pm10_avg': '38',
#   'so2_avg': '1',
#   'longitude': '120.292917',
#   'latitude': '22.674861',
#   'siteid': '54'},
#  {'sitename': '前金',
#   'county': '高雄市',
#   'aqi': '71',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.3',
#   'co': '0.46',
#   'o3': '26.5',
#   'o3_8hr': '12.8',
#   'pm10': '45',
#   'pm2.5': '27',
#   'no2': '18.6',
#   'nox': '27.7',
#   'no': '9',
#   'wind_speed': '2.2',
#   'wind_direc': '26',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '23',
#   'pm10_avg': '35',
#   'so2_avg': '1',
#   'longitude': '120.28676111',
#   'latitude': '22.63390278',
#   'siteid': '56'},
#  {'sitename': '前鎮',
#   'county': '高雄市',
#   'aqi': '77',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '2.5',
#   'co': '0.47',
#   'o3': '27.3',
#   'o3_8hr': '13.2',
#   'pm10': '45',
#   'pm2.5': '25',
#   'no2': '21.2',
#   'nox': '27.9',
#   'no': '6.7',
#   'wind_speed': '2.3',
#   'wind_direc': '357',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '26',
#   'pm10_avg': '38',
#   'so2_avg': '2',
#   'longitude': '120.30833356',
#   'latitude': '22.6044507',
#   'siteid': '57'},
#  {'sitename': '小港',
#   'county': '高雄市',
#   'aqi': '73',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.8',
#   'co': '0.4',
#   'o3': '26.2',
#   'o3_8hr': '9',
#   'pm10': '38',
#   'pm2.5': '26',
#   'no2': '22.7',
#   'nox': '32.8',
#   'no': '10.1',
#   'wind_speed': '1.7',
#   'wind_direc': '354',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '24',
#   'pm10_avg': '36',
#   'so2_avg': '1',
#   'longitude': '120.337736',
#   'latitude': '22.565833',
#   'siteid': '58'},
#  {'sitename': '屏東',
#   'county': '屏東縣',
#   'aqi': '61',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.2',
#   'co': '0.28',
#   'o3': '23.3',
#   'o3_8hr': '11.3',
#   'pm10': '39',
#   'pm2.5': '14',
#   'no2': '9.6',
#   'nox': '14.2',
#   'no': '4.5',
#   'wind_speed': '1.2',
#   'wind_direc': '334',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '19',
#   'pm10_avg': '39',
#   'so2_avg': '1',
#   'longitude': '120.488033',
#   'latitude': '22.673081',
#   'siteid': '59'},
#  {'sitename': '潮州',
#   'county': '屏東縣',
#   'aqi': '65',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.4',
#   'co': '0.32',
#   'o3': '23',
#   'o3_8hr': '6.6',
#   'pm10': '34',
#   'pm2.5': '19',
#   'no2': '9.7',
#   'nox': '13.8',
#   'no': '4',
#   'wind_speed': '1.2',
#   'wind_direc': '269',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '21',
#   'pm10_avg': '34',
#   'so2_avg': '1',
#   'longitude': '120.561175',
#   'latitude': '22.523108',
#   'siteid': '60'},
#  {'sitename': '恆春',
#   'county': '屏東縣',
#   'aqi': '30',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.1',
#   'co': '0.15',
#   'o3': '40.4',
#   'o3_8hr': '32.7',
#   'pm10': '6',
#   'pm2.5': '1',
#   'no2': '0.6',
#   'nox': '1.1',
#   'no': '0.5',
#   'wind_speed': '5.7',
#   'wind_direc': '19',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '2',
#   'pm10_avg': '5',
#   'so2_avg': '0',
#   'longitude': '120.788928',
#   'latitude': '21.958069',
#   'siteid': '61'},
#  {'sitename': '臺東',
#   'county': '臺東縣',
#   'aqi': '22',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.7',
#   'co': '0.23',
#   'o3': '30.2',
#   'o3_8hr': '24.5',
#   'pm10': '14',
#   'pm2.5': '1',
#   'no2': '6.1',
#   'nox': '9.9',
#   'no': '3.7',
#   'wind_speed': '2.3',
#   'wind_direc': '38',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '1',
#   'pm10_avg': '9',
#   'so2_avg': '0',
#   'longitude': '121.15045',
#   'latitude': '22.755358',
#   'siteid': '62'},
#  {'sitename': '花蓮',
#   'county': '花蓮縣',
#   'aqi': '21',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.7',
#   'co': '0.2',
#   'o3': '16.2',
#   'o3_8hr': '12.5',
#   'pm10': '',
#   'pm2.5': '7',
#   'no2': '',
#   'nox': '',
#   'no': '',
#   'wind_speed': '1.4',
#   'wind_direc': '219',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '6',
#   'pm10_avg': '12',
#   'so2_avg': '',
#   'longitude': '121.599769',
#   'latitude': '23.971306',
#   'siteid': '63'},
#  {'sitename': '陽明',
#   'county': '臺北市',
#   'aqi': '41',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.3',
#   'co': '0.21',
#   'o3': '44.9',
#   'o3_8hr': '44.1',
#   'pm10': '3',
#   'pm2.5': '0',
#   'no2': '1.1',
#   'nox': '1.7',
#   'no': '0.6',
#   'wind_speed': '',
#   'wind_direc': '',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '0',
#   'pm10_avg': '4',
#   'so2_avg': '0',
#   'longitude': '121.529583',
#   'latitude': '25.182722',
#   'siteid': '64'},
#  {'sitename': '宜蘭',
#   'county': '宜蘭縣',
#   'aqi': '22',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.2',
#   'co': '0.28',
#   'o3': '16.8',
#   'o3_8hr': '24.1',
#   'pm10': '5',
#   'pm2.5': '7',
#   'no2': '11.4',
#   'nox': '14',
#   'no': '2.6',
#   'wind_speed': '0.3',
#   'wind_direc': '90',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '3',
#   'pm10_avg': '6',
#   'so2_avg': '0',
#   'longitude': '121.746394',
#   'latitude': '24.747917',
#   'siteid': '65'},
#  {'sitename': '冬山',
#   'county': '宜蘭縣',
#   'aqi': '27',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.4',
#   'co': '0.23',
#   'o3': '29.3',
#   'o3_8hr': '29.2',
#   'pm10': '9',
#   'pm2.5': '3',
#   'no2': '12.2',
#   'nox': '17.8',
#   'no': '5.5',
#   'wind_speed': '1.8',
#   'wind_direc': '253',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '1',
#   'pm10_avg': '6',
#   'so2_avg': '0',
#   'longitude': '121.792928',
#   'latitude': '24.632203',
#   'siteid': '66'},
#  {'sitename': '三重',
#   'county': '新北市',
#   'aqi': '56',
#   'pollutant': '二氧化氮',
#   'status': '普通',
#   'so2': '1.2',
#   'co': '1.36',
#   'o3': '8.3',
#   'o3_8hr': '9',
#   'pm10': '20',
#   'pm2.5': '11',
#   'no2': '38',
#   'nox': '107.8',
#   'no': '69.8',
#   'wind_speed': '-',
#   'wind_direc': '-',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.9',
#   'pm2.5_avg': '8',
#   'pm10_avg': '13',
#   'so2_avg': '1',
#   'longitude': '121.493806',
#   'latitude': '25.072611',
#   'siteid': '67'},
#  {'sitename': '中壢',
#   'county': '桃園市',
#   'aqi': '54',
#   'pollutant': '二氧化氮',
#   'status': '普通',
#   'so2': '1.5',
#   'co': '0.99',
#   'o3': '7.2',
#   'o3_8hr': '16.8',
#   'pm10': '28',
#   'pm2.5': '11',
#   'no2': '35.8',
#   'nox': '66.5',
#   'no': '30.6',
#   'wind_speed': '0.8',
#   'wind_direc': '13',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.6',
#   'pm2.5_avg': '9',
#   'pm10_avg': '18',
#   'so2_avg': '1',
#   'longitude': '121.221667',
#   'latitude': '24.953278',
#   'siteid': '68'},
#  {'sitename': '竹山',
#   'county': '南投縣',
#   'aqi': '34',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1',
#   'co': '0.2',
#   'o3': '17.6',
#   'o3_8hr': '8.6',
#   'pm10': '15',
#   'pm2.5': '7',
#   'no2': '6.8',
#   'nox': '10.8',
#   'no': '3.9',
#   'wind_speed': '2.5',
#   'wind_direc': '9',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '10',
#   'pm10_avg': '19',
#   'so2_avg': '1',
#   'longitude': '120.677306',
#   'latitude': '23.756389',
#   'siteid': '69'},
#  {'sitename': '永和',
#   'county': '新北市',
#   'aqi': '28',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.8',
#   'co': '0.62',
#   'o3': '24.7',
#   'o3_8hr': '28.6',
#   'pm10': '11',
#   'pm2.5': '7',
#   'no2': '17.7',
#   'nox': '23.2',
#   'no': '5.4',
#   'wind_speed': '1.6',
#   'wind_direc': '96',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '6',
#   'pm10_avg': '7',
#   'so2_avg': '0',
#   'longitude': '121.516306',
#   'latitude': '25.017',
#   'siteid': '70'},
#  {'sitename': '復興',
#   'county': '高雄市',
#   'aqi': '70',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '1.5',
#   'co': '0.72',
#   'o3': '21.9',
#   'o3_8hr': '12.5',
#   'pm10': '61',
#   'pm2.5': '31',
#   'no2': '23.9',
#   'nox': '34.1',
#   'no': '10.2',
#   'wind_speed': '1.2',
#   'wind_direc': '117',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.5',
#   'pm2.5_avg': '23',
#   'pm10_avg': '39',
#   'so2_avg': '1',
#   'longitude': '120.312017',
#   'latitude': '22.608711',
#   'siteid': '71'},
#  {'sitename': '埔里',
#   'county': '南投縣',
#   'aqi': '33',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.3',
#   'co': '0.44',
#   'o3': '15.2',
#   'o3_8hr': '5.7',
#   'pm10': '32',
#   'pm2.5': '11',
#   'no2': '12.2',
#   'nox': '23',
#   'no': '10.8',
#   'wind_speed': '0.3',
#   'wind_direc': '77',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.3',
#   'pm2.5_avg': '10',
#   'pm10_avg': '22',
#   'so2_avg': '1',
#   'longitude': '120.967903',
#   'latitude': '23.968842',
#   'siteid': '72'},
#  {'sitename': '馬祖',
#   'county': '連江縣',
#   'aqi': '55',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '2.2',
#   'co': '0.33',
#   'o3': '33.1',
#   'o3_8hr': '40.6',
#   'pm10': '42',
#   'pm2.5': '16',
#   'no2': '8.2',
#   'nox': '9.2',
#   'no': '1',
#   'wind_speed': '2',
#   'wind_direc': '351',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '17',
#   'pm10_avg': '35',
#   'so2_avg': '1',
#   'longitude': '119.93149378',
#   'latitude': '26.15188416',
#   'siteid': '75'},
#  {'sitename': '金門',
#   'county': '金門縣',
#   'aqi': '55',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '2.5',
#   'co': '0.25',
#   'o3': '29.1',
#   'o3_8hr': '24.8',
#   'pm10': '35',
#   'pm2.5': '15',
#   'no2': '11.4',
#   'nox': '14.8',
#   'no': '3.3',
#   'wind_speed': '3.1',
#   'wind_direc': '26',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '17',
#   'pm10_avg': '33',
#   'so2_avg': '2',
#   'longitude': '118.312256',
#   'latitude': '24.432133',
#   'siteid': '77'},
#  {'sitename': '馬公',
#   'county': '澎湖縣',
#   'aqi': '40',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.6',
#   'co': '0.19',
#   'o3': '44.6',
#   'o3_8hr': '43.9',
#   'pm10': '18',
#   'pm2.5': '4',
#   'no2': '1.9',
#   'nox': '2.7',
#   'no': '0.8',
#   'wind_speed': '5.8',
#   'wind_direc': '25',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '6',
#   'pm10_avg': '15',
#   'so2_avg': '0',
#   'longitude': '119.566158',
#   'latitude': '23.569031',
#   'siteid': '78'},
#  {'sitename': '關山',
#   'county': '臺東縣',
#   'aqi': '16',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.1',
#   'co': '0.14',
#   'o3': '21.6',
#   'o3_8hr': '12.5',
#   'pm10': '7',
#   'pm2.5': '6',
#   'no2': '3',
#   'nox': '4.4',
#   'no': '1.4',
#   'wind_speed': '0.8',
#   'wind_direc': '5',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '5',
#   'pm10_avg': '7',
#   'so2_avg': '0',
#   'longitude': '121.161933',
#   'latitude': '23.045083',
#   'siteid': '80'},
#  {'sitename': '麥寮',
#   'county': '雲林縣',
#   'aqi': '29',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.6',
#   'co': '0.23',
#   'o3': '39',
#   'o3_8hr': '31.3',
#   'pm10': '14',
#   'pm2.5': '8',
#   'no2': '5.7',
#   'nox': '7.4',
#   'no': '1.6',
#   'wind_speed': '4.8',
#   'wind_direc': '3',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '7',
#   'pm10_avg': '19',
#   'so2_avg': '1',
#   'longitude': '120.251825',
#   'latitude': '23.753506',
#   'siteid': '83'},
#  {'sitename': '富貴角',
#   'county': '新北市',
#   'aqi': '46',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0',
#   'co': '0.17',
#   'o3': '49.8',
#   'o3_8hr': '50',
#   'pm10': '29',
#   'pm2.5': '10',
#   'no2': '1.3',
#   'nox': '1.4',
#   'no': '0.1',
#   'wind_speed': '8.4',
#   'wind_direc': '35',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '8',
#   'pm10_avg': '24',
#   'so2_avg': '0',
#   'longitude': '121.53656894',
#   'latitude': '25.29681695',
#   'siteid': '84'},
#  {'sitename': '大城',
#   'county': '彰化縣',
#   'aqi': '32',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.4',
#   'co': '0.2',
#   'o3': '36.5',
#   'o3_8hr': '35.6',
#   'pm10': '20',
#   'pm2.5': '7',
#   'no2': '7',
#   'nox': '9.4',
#   'no': '2.4',
#   'wind_speed': '7.4',
#   'wind_direc': '34',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '5',
#   'pm10_avg': '15',
#   'so2_avg': '1',
#   'longitude': '120.26964167',
#   'latitude': '23.85493056',
#   'siteid': '85'},
#  {'sitename': '高雄(湖內)',
#   'county': '高雄市',
#   'aqi': '53',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '2.9',
#   'co': '0.27',
#   'o3': '22.4',
#   'o3_8hr': '9.8',
#   'pm10': '22',
#   'pm2.5': '10',
#   'no2': '10.8',
#   'nox': '14.9',
#   'no': '4.1',
#   'wind_speed': '1.3',
#   'wind_direc': '71',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '16',
#   'pm10_avg': '25',
#   'so2_avg': '2',
#   'longitude': '120.24535',
#   'latitude': '22.87985556',
#   'siteid': '202'},
#  {'sitename': '臺南(麻豆)',
#   'county': '臺南市',
#   'aqi': '37',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '1.7',
#   'co': '0.27',
#   'o3': '21',
#   'o3_8hr': '12.8',
#   'pm10': '26',
#   'pm2.5': '11',
#   'no2': '10',
#   'nox': '14.2',
#   'no': '4.1',
#   'wind_speed': '2.5',
#   'wind_direc': '344',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '11',
#   'pm10_avg': '22',
#   'so2_avg': '1',
#   'longitude': '120.24583056',
#   'latitude': '23.17904722',
#   'siteid': '203'},
#  {'sitename': '屏東(琉球)',
#   'county': '屏東縣',
#   'aqi': '84',
#   'pollutant': '細懸浮微粒',
#   'status': '普通',
#   'so2': '2.7',
#   'co': '0.4',
#   'o3': '29.7',
#   'o3_8hr': '10.3',
#   'pm10': '49',
#   'pm2.5': '32',
#   'no2': '25.3',
#   'nox': '32.9',
#   'no': '7.6',
#   'wind_speed': '1.3',
#   'wind_direc': '334',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.4',
#   'pm2.5_avg': '28',
#   'pm10_avg': '50',
#   'so2_avg': '3',
#   'longitude': '120.37722',
#   'latitude': '22.35222',
#   'siteid': '204'},
#  {'sitename': '宜蘭(壯圍)',
#   'county': '宜蘭縣',
#   'aqi': '29',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.4',
#   'co': '0.28',
#   'o3': '23.5',
#   'o3_8hr': '31.7',
#   'pm10': '9',
#   'pm2.5': '6',
#   'no2': '13.3',
#   'nox': '18.7',
#   'no': '5.4',
#   'wind_speed': '0.3',
#   'wind_direc': '94',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '6',
#   'pm10_avg': '16',
#   'so2_avg': '0',
#   'longitude': '121.815708',
#   'latitude': '24.765468',
#   'siteid': '310'},
#  {'sitename': '新北(樹林)',
#   'county': '新北市',
#   'aqi': '32',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.5',
#   'co': '0.37',
#   'o3': '21.4',
#   'o3_8hr': '21.8',
#   'pm10': '12',
#   'pm2.5': '6',
#   'no2': '19.9',
#   'nox': '26.9',
#   'no': '6.9',
#   'wind_speed': '0',
#   'wind_direc': '171',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '6',
#   'pm10_avg': '10',
#   'so2_avg': '0',
#   'longitude': '121.38352778',
#   'latitude': '24.94902778',
#   'siteid': '311'},
#  {'sitename': '臺南(學甲)',
#   'county': '臺南市',
#   'aqi': '34',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.9',
#   'co': '0.3',
#   'o3': '24.5',
#   'o3_8hr': '21',
#   'pm10': '44',
#   'pm2.5': '12',
#   'no2': '13.7',
#   'nox': '25.2',
#   'no': '11.4',
#   'wind_speed': '2.7',
#   'wind_direc': '23',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.2',
#   'pm2.5_avg': '10',
#   'pm10_avg': '28',
#   'so2_avg': '0',
#   'longitude': '120.18339722',
#   'latitude': '23.23688056',
#   'siteid': '312'},
#  {'sitename': '屏東(枋山)',
#   'county': '屏東縣',
#   'aqi': '34',
#   'pollutant': '',
#   'status': '良好',
#   'so2': '0.5',
#   'co': '0.23',
#   'o3': '28.8',
#   'o3_8hr': '22.7',
#   'pm10': '47',
#   'pm2.5': '15',
#   'no2': '6',
#   'nox': '8.1',
#   'no': '2.1',
#   'wind_speed': '3',
#   'wind_direc': '307',
#   'publishtime': '2022/12/08 10:00:00',
#   'co_8hr': '0.1',
#   'pm2.5_avg': '10',
#   'pm10_avg': '24',
#   'so2_avg': '0',
#   'longitude': '120.651472',
#   'latitude': '22.260899',
#   'siteid': '313'}]

# %% [markdown]
# ## 1.建立 ipython 介面，以下拉式選單選擇縣市(county)之後列出該縣市所有測站於另一個下拉式選單 ##
# ### 例如選擇"臺北市"，應該會出現七個測站[中山、古亭、萬華...  等] ###

# %%
# TODO: Pandas DataFrame
df = pd.DataFrame(content)
df['county'] = df['county'].astype('category')
df['sitename'] = df['sitename'].astype('category')
df['aqi'] = df['aqi'].astype('float64') # 將aqi轉換為小數
df
# Out:
#    sitename county   aqi pollutant status  so2    co    o3 o3_8hr pm10  ...  \
# 0        基隆    基隆市  39.0               良好  1.3  0.25  39.8   42.2   21  ...
# 1        汐止    新北市  31.0               良好  0.2  0.27  33.3   33.8    4  ...
# 2        萬里    新北市  42.0               良好  0.4  0.19  45.8   45.6   45  ...
# 3        新店    新北市  28.0               良好  0.7  0.38  27.2   28.9    7  ...
# 4        土城    新北市  31.0               良好  0.8  0.35  28.9   33.3   10  ...
# ..      ...    ...   ...       ...    ...  ...   ...   ...    ...  ...  ...
# 80   屏東(琉球)    屏東縣  84.0     細懸浮微粒     普通  2.7   0.4  29.7   10.3   49  ...
# 81   宜蘭(壯圍)    宜蘭縣  29.0               良好  0.4  0.28  23.5   31.7    9  ...
# 82   新北(樹林)    新北市  32.0               良好  0.5  0.37  21.4   21.8   12  ...
# 83   臺南(學甲)    臺南市  34.0               良好  0.9   0.3  24.5     21   44  ...
# 84   屏東(枋山)    屏東縣  34.0               良好  0.5  0.23  28.8   22.7   47  ...
#
#    wind_speed wind_direc          publishtime co_8hr pm2.5_avg pm10_avg  \
# 0         0.9         66  2022/12/08 10:00:00    0.2         6       15
# 1           2         48  2022/12/08 10:00:00    0.2         4        7
# 2         5.1         19  2022/12/08 10:00:00    0.1        10       35
# 3         0.9        115  2022/12/08 10:00:00    0.2         3        6
# 4         1.5         66  2022/12/08 10:00:00    0.2         2        8
# ..        ...        ...                  ...    ...       ...      ...
# 80        1.3        334  2022/12/08 10:00:00    0.4        28       50
# 81        0.3         94  2022/12/08 10:00:00    0.2         6       16
# 82          0        171  2022/12/08 10:00:00    0.2         6       10
# 83        2.7         23  2022/12/08 10:00:00    0.2        10       28
# 84          3        307  2022/12/08 10:00:00    0.1        10       24
#
#    so2_avg     longitude     latitude siteid
# 0        0    121.760056    25.129167      1
# 1        0      121.6423    25.067131      2
# 2        0    121.689881    25.179667      3
# 3        0    121.537778    24.977222      4
# 4        0    121.451861    24.982528      5
# ..     ...           ...          ...    ...
# 80       3     120.37722     22.35222    204
# 81       0    121.815708    24.765468    310
# 82       0  121.38352778  24.94902778    311
# 83       0  120.18339722  23.23688056    312
# 84       0    120.651472    22.260899    313
#
# [85 rows x 24 columns]

# %%
# TODO: 先確認有哪些county
df['county'].cat.categories
# Out:
# Index(['南投縣', '嘉義市', '嘉義縣', '基隆市', '宜蘭縣', '屏東縣', '彰化縣', '新北市', '新竹市', '新竹縣',
#        '桃園市', '澎湖縣', '臺中市', '臺北市', '臺南市', '臺東縣', '花蓮縣', '苗栗縣', '連江縣', '金門縣',
#        '雲林縣', '高雄市'],
#       dtype='object')

# %%
ComboBox = widgets.Dropdown(
        options=df['county'].cat.categories,
        description='county：',
        value='臺北市',
        disabled=True)


def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        print(change['new'])

ComboBox.observe(on_change)

ComboBox
# Out:
# Dropdown(description='county：', disabled=True, index=13, options=('南投縣', '嘉義市', '嘉義縣', '基隆市', '宜蘭縣', '屏東縣', '彰…

# %%
Selected_County = ComboBox.label
Selected_County
# Out:
# '臺北市'

# %%
# Pandas DataFrame Filter
df[df['county'] == Selected_County]
# Out:
#    sitename county   aqi pollutant status  so2    co    o3 o3_8hr pm10  ...  \
# 10       士林    臺北市  38.0               良好  0.8  0.37  18.4   21.4   23  ...
# 11       中山    臺北市  42.0               良好    1  0.61  18.8   24.2   15  ...
# 12       萬華    臺北市  47.0               良好  0.7  0.52  15.1   20.1   15  ...
# 13       古亭    臺北市  30.0               良好  0.3  0.38  25.4   32.2    9  ...
# 14       松山    臺北市  37.0               良好  0.8  0.37  22.8   29.6   16  ...
# 15       大同    臺北市  55.0      二氧化氮     普通  0.8  1.13   9.4   13.1   25  ...
# 62       陽明    臺北市  41.0               良好  1.3  0.21  44.9   44.1    3  ...
#
#    wind_speed wind_direc          publishtime co_8hr pm2.5_avg pm10_avg  \
# 10        1.1        258  2022/12/08 10:00:00    0.3         5       12
# 11        2.4        118  2022/12/08 10:00:00    0.4         4        9
# 12        2.4        102  2022/12/08 10:00:00    0.3         7        8
# 13        1.8         58  2022/12/08 10:00:00    0.2         8        8
# 14        2.6         62  2022/12/08 10:00:00    0.2         6       13
# 15          -          -  2022/12/08 10:00:00      1        11       22
# 62                        2022/12/08 10:00:00    0.1         0        4
#
#    so2_avg     longitude     latitude siteid
# 10       0  121.51666356  25.10334003     11
# 11       0    121.526528    25.062361     12
# 12       0    121.507972    25.046503     13
# 13       0    121.529556    25.020608     14
# 14       0    121.578611        25.05     15
# 15       0  121.51342074  25.06331455     16
# 62       0    121.529583    25.182722     64
#
# [7 rows x 24 columns]

# %% [markdown]
# ## 2.選擇測站之後列出該測站的任意五個屬性(自選) ##

# %%
# TODO: 再確認有哪些sitename
df[df['county'] == Selected_County]['sitename']
# Out:
# 10    士林
# 11    中山
# 12    萬華
# 13    古亭
# 14    松山
# 15    大同
# 62    陽明
# Name: sitename, dtype: category
# Categories (85, object): ['三義', '三重', '中壢', '中山', ..., '高雄(湖內)', '鳳山', '麥寮', '龍潭']

# %%
ComboBox = widgets.Dropdown(
        options=df[df['county'] == Selected_County]['sitename'],
        description='sitename：',
        value='中山',
        disabled=True)


def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        print(change['new'])

ComboBox.observe(on_change)

ComboBox
# Out:
# Dropdown(description='sitename：', disabled=True, index=1, options=('士林', '中山', '萬華', '古亭', '松山', '大同', '陽明'), …

# %%
Selected_sitename = ComboBox.label
Selected_sitename
# Out:
# '中山'

# %%
df_sitename_filtered = df[df['county'] == Selected_County][df['sitename'] == Selected_sitename]
print(f"status:{df_sitename_filtered['status']}")
print(f"co:{df_sitename_filtered['co']}")
print(f"pm2.5:{df_sitename_filtered['pm2.5']}")
print(f"so2:{df_sitename_filtered['so2']}")
print(f"no2:{df_sitename_filtered['no2']}")
# Out:
# status:11    良好
# Name: status, dtype: object
# co:11    0.61
# Name: co, dtype: object
# pm2.5:11    5
# Name: pm2.5, dtype: object
# so2:11    1
# Name: so2, dtype: object
# no2:11    25.5
# Name: no2, dtype: object
# <ipython-input-11-50866e616321>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_sitename_filtered = df[df['county'] == Selected_County][df['sitename'] == Selected_sitename]

# %% [markdown]
# ## 3.顯示本日全台灣 AQI 前五糟糕的測站 (使用 pandas，以 aqi 排序之後顯示 SiteName 欄位) ##
# ### AQI空氣品質指標，數值越大，代表空氣汙染狀況越嚴重，對人體的健康危害也就越大。 ###

# %%
df.sort_values(by='aqi', ascending=False)[0:5]['sitename']
# Out:
# 80    屏東(琉球)
# 49        鳳山
# 55        前鎮
# 56        小港
# 50        大寮
# Name: sitename, dtype: category
# Categories (85, object): ['三義', '三重', '中壢', '中山', ..., '高雄(湖內)', '鳳山', '麥寮', '龍潭']

# %% [markdown]
# ## 4.顯示本日全台灣 平均 AQI 前五糟糕的縣市 (使用 pandas，先計算各縣市的平均 AQI，再顯示 County 欄位) ##

# %%
df_AQI_Averages = pd.DataFrame(df['county'].cat.categories, columns=['各縣市']) 

# 計算各縣市的平均 AQI
Calculate_SiteNames = list()
Calculate_Sum_AQI = list()
Calculate_Average_AQI = list()
for county in df['county'].cat.categories:
    Calculate_SiteNames.append(df[df['county'] == county].shape[0])
    Calculate_Sum_AQI.append(df[df['county'] == county].sum()['aqi'])
    Calculate_Average_AQI.append(df[df['county'] == county].sum()['aqi']/df[df['county'] == county].shape[0])
    
df_AQI_Averages['測站數量']=Calculate_SiteNames
df_AQI_Averages['總計AQI']=Calculate_Sum_AQI
df_AQI_Averages['平均AQI']=Calculate_Average_AQI
df_AQI_Averages.sort_values(by='平均AQI', ascending=False)[0:5]['各縣市']
# Out:
# <ipython-input-13-1bcf0a3340f4>:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Calculate_Sum_AQI.append(df[df['county'] == county].sum()['aqi'])
# <ipython-input-13-1bcf0a3340f4>:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Calculate_Average_AQI.append(df[df['county'] == county].sum()['aqi']/df[df['county'] == county].shape[0])
# 21    高雄市
# 19    金門縣
# 18    連江縣
# 5     屏東縣
# 10    桃園市
# Name: 各縣市, dtype: object

# %% [markdown]
# ## 5. 選用matplotlib ##
# ## 6. 選擇縣市之後，把該縣市所有測站的 AQI 以長條圖顯示出來 ##

# %%
# 以'臺北市'為例，畫出所有測站的 AQI 
df_sitename_filtered = df[df['county'] == '臺北市']
df_sitename_filtered
# Out:
#    sitename county   aqi pollutant status  so2    co    o3 o3_8hr pm10  ...  \
# 10       士林    臺北市  38.0               良好  0.8  0.37  18.4   21.4   23  ...
# 11       中山    臺北市  42.0               良好    1  0.61  18.8   24.2   15  ...
# 12       萬華    臺北市  47.0               良好  0.7  0.52  15.1   20.1   15  ...
# 13       古亭    臺北市  30.0               良好  0.3  0.38  25.4   32.2    9  ...
# 14       松山    臺北市  37.0               良好  0.8  0.37  22.8   29.6   16  ...
# 15       大同    臺北市  55.0      二氧化氮     普通  0.8  1.13   9.4   13.1   25  ...
# 62       陽明    臺北市  41.0               良好  1.3  0.21  44.9   44.1    3  ...
#
#    wind_speed wind_direc          publishtime co_8hr pm2.5_avg pm10_avg  \
# 10        1.1        258  2022/12/08 10:00:00    0.3         5       12
# 11        2.4        118  2022/12/08 10:00:00    0.4         4        9
# 12        2.4        102  2022/12/08 10:00:00    0.3         7        8
# 13        1.8         58  2022/12/08 10:00:00    0.2         8        8
# 14        2.6         62  2022/12/08 10:00:00    0.2         6       13
# 15          -          -  2022/12/08 10:00:00      1        11       22
# 62                        2022/12/08 10:00:00    0.1         0        4
#
#    so2_avg     longitude     latitude siteid
# 10       0  121.51666356  25.10334003     11
# 11       0    121.526528    25.062361     12
# 12       0    121.507972    25.046503     13
# 13       0    121.529556    25.020608     14
# 14       0    121.578611        25.05     15
# 15       0  121.51342074  25.06331455     16
# 62       0    121.529583    25.182722     64
#
# [7 rows x 24 columns]

# %%
# 因為matplotlib不接受中文，所以要轉為英文。
sitename_english = {'士林':'Shilin', '中山':'zhongshan', '萬華':'Wanhua', '古亭':'Guting', '松山':'Songshan', '大同':'Datong', '陽明':'YangMing'}
df_sitename_filtered["sitename"] = df_sitename_filtered["sitename"].replace(sitename_english)
df_sitename_filtered
# Out:
# <ipython-input-15-1c4b57a68401>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sitename_filtered["sitename"] = df_sitename_filtered["sitename"].replace(sitename_english)
#      sitename county   aqi pollutant status  so2    co    o3 o3_8hr pm10  ...  \
# 10     Shilin    臺北市  38.0               良好  0.8  0.37  18.4   21.4   23  ...
# 11  zhongshan    臺北市  42.0               良好    1  0.61  18.8   24.2   15  ...
# 12     Wanhua    臺北市  47.0               良好  0.7  0.52  15.1   20.1   15  ...
# 13     Guting    臺北市  30.0               良好  0.3  0.38  25.4   32.2    9  ...
# 14   Songshan    臺北市  37.0               良好  0.8  0.37  22.8   29.6   16  ...
# 15     Datong    臺北市  55.0      二氧化氮     普通  0.8  1.13   9.4   13.1   25  ...
# 62   YangMing    臺北市  41.0               良好  1.3  0.21  44.9   44.1    3  ...
#
#    wind_speed wind_direc          publishtime co_8hr pm2.5_avg pm10_avg  \
# 10        1.1        258  2022/12/08 10:00:00    0.3         5       12
# 11        2.4        118  2022/12/08 10:00:00    0.4         4        9
# 12        2.4        102  2022/12/08 10:00:00    0.3         7        8
# 13        1.8         58  2022/12/08 10:00:00    0.2         8        8
# 14        2.6         62  2022/12/08 10:00:00    0.2         6       13
# 15          -          -  2022/12/08 10:00:00      1        11       22
# 62                        2022/12/08 10:00:00    0.1         0        4
#
#    so2_avg     longitude     latitude siteid
# 10       0  121.51666356  25.10334003     11
# 11       0    121.526528    25.062361     12
# 12       0    121.507972    25.046503     13
# 13       0    121.529556    25.020608     14
# 14       0    121.578611        25.05     15
# 15       0  121.51342074  25.06331455     16
# 62       0    121.529583    25.182722     64
#
# [7 rows x 24 columns]

# %%
plt.figure(figsize=(20, 15))
plt.xlabel("aqi", fontsize=16)
plt.ylabel("sitename", fontsize=16)
plt.title("Taipei", fontsize=24)
plt.barh(df_sitename_filtered["sitename"], df_sitename_filtered["aqi"], color=['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'], height=0.5)
for a,b in zip(df_sitename_filtered["aqi"], df_sitename_filtered["sitename"]): plt.text(a,b, '  '+str(a), ha='left', va='bottom', fontsize=12) # 顯示數據標籤
